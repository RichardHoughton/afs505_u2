# %% [markdown]
# # Lesson 7 Practice: Matplotlib
#
# Use this notebook to follow along with the lesson in the corresponding lesson notebook: [L07-Matplotlib-Lesson.ipynb](./L07-Matplotlib-Lesson.ipynb).

# %% [markdown]
# ## Instructions
# Follow along with the teaching material in the lesson. Throughout the tutorial sections labeled as "Tasks" are interspersed and indicated with the icon: ![Task](http://icons.iconarchive.com/icons/sbstnblnd/plateau/16/Apps-gnome-info-icon.png). You should follow the instructions provided in these sections by performing them in the practice notebook.  When the tutorial is completed you can turn in the final practice notebook. For each task, use the cell below it to write and test your code.  You may add additional cells for any task as needed or desired.

# %% [markdown]
# ## Task 1a: Setup
#
# Import the following packages:
# + `pandas` as `pd`
# + `numpy` as `np`
# + `matplotlib.pyplot` as `plt`
#
# Activate the `%matplotlib inline` magic.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 1b: Load Data
#
# Load the Iris data (same as in the Pandas tasks).

# %%
iris_df = pd.read_csv('data/iris.csv')
iris_df.head(2)
iris_df['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ## Task 2a: Create a figure
#
# Create the a scatter plot using the iris data, but compare `petal_width` to `petal_length`.  Be sure to add labels to the axes.

# %%
iris_fig = plt.figure()
iris_ax = iris_fig.add_subplot(1, 1, 1)
iris_ax.scatter(iris_df['petal_width'], iris_df['petal_length'])

iris_ax.axes.set_xlabel('Petal Width')
iris_ax.axes.set_ylabel('Petal Length')

iris_ax.set_title('Petal Width vs Length')

plt.show()

# %% [markdown]
# ## Task 3a: Figure Style
#
# Create a scatter plots using the iris data frame. Do not convert the data frame columns to numpy arrays. Rather use the dataframe as is. Be sure to:
# - plot `petal_length` vs `petal_width`.
# - Use column names to specify the x and y coordinates (don't pass in Numpy arrays)
# - Color each dot by the species (you'll need to be creative to do this).
#   - Hint 1: use the [pd.Series.replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) function to convert species names to colors).
#   - Hint 2: Use the color abbreviations we learned for the the plot function (e.g. 'r', 'b', 'g', etc.).
# - Add axis labels

# %%
iris_df['species'] = iris_df['species'].replace(['versicolor', 'setosa', 'virginica'], ['r', 'b', 'g'])

iris_fig2 = plt.figure()
iris_ax2 = iris_fig2.add_subplot(1, 1, 1)
iris_ax2.scatter('petal_length', 'petal_width', color='species', data=iris_df)
iris_ax2.axes.set_xlabel('Petal Length')
iris_ax2.axes.set_ylabel('Petal Width')
iris_ax2.set_title('Petal Length vs Width')
plt.show()

# %% [markdown]
# ## Task 4a: Categorical plots
#
# Create a bar graph that indicates the mean `sepal_length` of each subspecies.

# %%
species = ['versicolor', 'setosa', 'virginica']
sepal_length = iris_df.groupby(['species']).mean()['sepal_length']

iris_fig3 = plt.figure(figsize=(5, 5))
iris_ax1 = iris_fig3.add_subplot(1, 1, 1)
iris_ax1.bar(species, sepal_length)
iris_fig3.suptitle('Mean Sepal Length of Each Subspecies')
plt.show()

# %% [markdown]
# ## Task 6a:  Multiple Plots
#
# Create 4 scatterplots for the iris data all in one figure. The figure should include scatterplots of these comparisions:
# - `sepal_length` x `petal_length`
# - `sepal_length` x `petal_width`
# - `sepal_width` x `petal_length`
# - `sepal_width` x `petal_width`
#
# Be sure that:
# - the points for the species
# - the axes for each plot are labeled
# - the figure has a label.

# %%
iris_fig4 = plt.figure()
iris_axes = iris_fig4.subplots(2, 2)
iris_df['species'] = iris_df['species'].replace(['versicolor', 'setosa', 'virginica'], ['r', 'b', 'g'])

iris_axes[0, 0].scatter('sepal_length', 'petal_length', color='species', data=iris_df)
iris_axes[0, 0].axes.set_xlabel('Sepal Length')
iris_axes[0, 0].axes.set_ylabel('Petal Length')
iris_axes[0, 0].set_title('Sepal Length vs Petal Length')

iris_axes[0, 1].scatter('sepal_length', 'petal_width', color='species', data=iris_df)
iris_axes[0, 1].axes.set_xlabel('Sepal Length')
iris_axes[0, 1].axes.set_ylabel('Petal Width')
iris_axes[0, 1].set_title('Sepal Length vs Petal Width')

iris_axes[1, 0].scatter('sepal_width', 'petal_length', color='species', data=iris_df)
iris_axes[1, 0].axes.set_xlabel('Sepal Width')
iris_axes[1, 0].axes.set_ylabel('Petal Length')
iris_axes[1, 0].set_title('Sepal Width vs Petal Length')

iris_axes[1, 1].scatter('sepal_width', 'petal_width', color='species', data=iris_df)
iris_axes[1, 1].axes.set_xlabel('Sepal Width')
iris_axes[1, 1].axes.set_ylabel('Petal Width')
iris_axes[1, 1].set_title('Sepal Width vs Petal Width')
plt.show()
